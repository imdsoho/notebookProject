# %%
import sys
import gurobipy as gp
from gurobipy import GRB

# %%
m = gp.Model("lp1")

# %%
sa_buy_barrel = m.addVar(name="sa_buy_barrel", vtype=GRB.INTEGER, lb=0)
ve_buy_barrel = m.addVar(name="ve_buy_barrel", vtype=GRB.INTEGER, lb=0)

# %%
SA_MONEY_PER_BARREL = 20            # 배럴 당 금액
VE_MONEY_PER_BARREL = 15

SA_BUY_AMOUNT_PER_DAY = 9000        # 구매 최대량
VE_BUY_AMOUNT_PER_DAY = 6000

SA_GAS = 0.3                        # 원유 배럴당 생산할 수 있는 제품 양
SA_JET = 0.4
SA_LUB = 0.2
SA_TSH = 0.1

VE_GAS = 0.4
VE_JET = 0.2
VE_LUB = 0.3
VE_TSH = 0.1

GOAL_GAS = 2000                     # 납품 해야 할 제품의 양
GOAL_JET = 1500
GOAL_LUB = 500

# %%
m.setObjective(sa_buy_barrel*SA_MONEY_PER_BARREL + ve_buy_barrel*VE_MONEY_PER_BARREL, GRB.MINIMIZE)

# %%
m.addConstr(sa_buy_barrel >= 0, name="c1")
m.addConstr(ve_buy_barrel >= 0, name="c2")

m.addConstr(sa_buy_barrel * SA_GAS + ve_buy_barrel * VE_GAS >= GOAL_GAS, name="c3")
m.addConstr(sa_buy_barrel * SA_JET + ve_buy_barrel * VE_JET >= GOAL_JET, name="c4")
m.addConstr(sa_buy_barrel * SA_LUB + ve_buy_barrel * VE_LUB >= GOAL_LUB, name="c5")

m.addConstr(sa_buy_barrel <= SA_BUY_AMOUNT_PER_DAY, name="c6")      # 구매 최대량 제약
m.addConstr(ve_buy_barrel  <= VE_BUY_AMOUNT_PER_DAY, name="c7")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i3-12100, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7 rows, 2 columns and 10 nonzeros (Min)
# Model fingerprint: 0x74477985
# Model has 2 linear objective coefficients
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [2e+01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+02, 9e+03]
#
# Presolve removed 5 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 2 columns, 4 nonzeros
# Variable types: 0 continuous, 2 integer (0 binary)
# Found heuristic solution: objective 133340.00000
# Found heuristic solution: objective 105000.00000
# Found heuristic solution: objective 104990.00000
#
# Root relaxation: objective 9.250000e+04, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    92500.000000 92500.0000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 92500 104990 105000 133340
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.250000000000e+04, best bound 9.250000000000e+04, gap 0.0000%

# %%
if m.status == GRB.OPTIMAL:
    print('Optimal solution found')
else:
    print('Optimal solution Not found')

for v in m.getVars():
    print('%s %g' % (v.varName, v.x))

print('Obj: %g' % m.objVal)
# Out:
# Optimal solution found
# sa_buy_barrel 2000
# ve_buy_barrel 3500
# Obj: 92500
