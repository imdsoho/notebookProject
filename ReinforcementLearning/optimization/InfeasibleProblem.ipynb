# %%
import sys
import gurobipy as gp
from gurobipy import GRB

# %%
m = gp.Model("lp1")

# %%
meter = m.addVar(name="meter", vtype=GRB.INTEGER)

# %%
END_LINE = 100

# %%
m.setObjective(meter/2, GRB.MINIMIZE)

# %%
m.addConstr(meter == END_LINE/2, name="c1")
m.addConstr(meter == 0, name="c2")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i3-12100, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2 rows, 1 columns and 2 nonzeros (Min)
# Model fingerprint: 0x5130eb2b
# Model has 1 linear objective coefficients
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 5e+01]
#
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -

# %%
if m.status == GRB.OPTIMAL:
    print('Optimal solution found')
elif m.status == GRB.UNBOUNDED:
    print('Unbounded solution found')
elif m.status == GRB.INFEASIBLE:
    print('Infeasible solution found')
else:
    print('Optimal solution Not found')

for v in m.getVars():
    print('%s %g' % (v.varName, v.x))

print('Obj: %g' % m.objVal)
# Out:
# Infeasible solution found
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[175], line 11
#       8     print('Optimal solution Not found')
#      10 for v in m.getVars():
# ---> 11     print('%s %g' % (v.varName, v.x))
#      13 print('Obj: %g' % m.objVal)
#
# File src/gurobipy/var.pxi:128, in gurobipy._core.Var.__getattr__()
#
# File src/gurobipy/var.pxi:156, in gurobipy._core.Var.getAttr()
#
# File src/gurobipy/_attrutil.pyx:119, in gurobipy._attrutil._getattr()
#
# AttributeError: Unable to retrieve attribute 'x'
